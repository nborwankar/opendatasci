# %%
x=arange(0,3,0.1)
y=sin(x)
plot(x,y)
myplot=gca()
line = myplot.lines[0]
setp(line, color='g')
setp(line, marker='3')
setp(line, markersize=5)
legend(('sine',),loc='upper left')
grid(True)

# %%
clf()
plot(arange(10))
t1 = text(5,5,'Text in the middle')
t2 = figtext(0.8, 0.8, 'Upper right text')
ax = gca()
ax.annotate("Here is something special", xy=(1,1))

# %%
plot(arange(10))
t1 = text(5,5,'Text in the middle')
t2 = figtext(0.8, 0.8, 'Upper right text')
ax = annotate("here is something special", xy=(1,1))
myplot = gca()
line = myplot.lines[0]
line.axes.annotate('My text', xy=(1,1), xytext=(1,5),arrowprops={'facecolor':'r'})
text(5,7,r'$ 2\pi r $') 
draw()
#ticks

# %%
#ticks
#plot(arange(10))

major_locator = MultipleLocator(2)
major_formatter = FormatStrFormatter('%5.2f')
minor_locator = MultipleLocator(1)
#minor_formatter = FormatStrFormatter('%i')

#plot(arange(10))
lines = plot(arange(10))
line = lines[0]
line.axes.xaxis.set_major_locator(major_locator)
line.axes.xaxis.set_minor_locator(minor_locator)
line.axes.xaxis.set_major_formatter(major_formatter)
#line.axes.yaxis.set_minor_formatter(minor_formatter)
draw()

# %%
# generating dates

# %%
import datetime as dt

# %%
d = [dt.datetime(2000,m,1) for m in range(1,13)]

# %%
d
# Out:
# [datetime.datetime(2000, 1, 1, 0, 0),
#  datetime.datetime(2000, 2, 1, 0, 0),
#  datetime.datetime(2000, 3, 1, 0, 0),
#  datetime.datetime(2000, 4, 1, 0, 0),
#  datetime.datetime(2000, 5, 1, 0, 0),
#  datetime.datetime(2000, 6, 1, 0, 0),
#  datetime.datetime(2000, 7, 1, 0, 0),
#  datetime.datetime(2000, 8, 1, 0, 0),
#  datetime.datetime(2000, 9, 1, 0, 0),
#  datetime.datetime(2000, 10, 1, 0, 0),
#  datetime.datetime(2000, 11, 1, 0, 0),
#  datetime.datetime(2000, 12, 1, 0, 0)]

# %%
delta = dt.timedelta(days=20)
d2 = [dt.datetime(2013,2,3) + x * delta for x in range(30)]

# %%
d2
# Out:
# [datetime.datetime(2013, 2, 3, 0, 0),
#  datetime.datetime(2013, 2, 23, 0, 0),
#  datetime.datetime(2013, 3, 15, 0, 0),
#  datetime.datetime(2013, 4, 4, 0, 0),
#  datetime.datetime(2013, 4, 24, 0, 0),
#  datetime.datetime(2013, 5, 14, 0, 0),
#  datetime.datetime(2013, 6, 3, 0, 0),
#  datetime.datetime(2013, 6, 23, 0, 0),
#  datetime.datetime(2013, 7, 13, 0, 0),
#  datetime.datetime(2013, 8, 2, 0, 0),
#  datetime.datetime(2013, 8, 22, 0, 0),
#  datetime.datetime(2013, 9, 11, 0, 0),
#  datetime.datetime(2013, 10, 1, 0, 0),
#  datetime.datetime(2013, 10, 21, 0, 0),
#  datetime.datetime(2013, 11, 10, 0, 0),
#  datetime.datetime(2013, 11, 30, 0, 0),
#  datetime.datetime(2013, 12, 20, 0, 0),
#  datetime.datetime(2014, 1, 9, 0, 0),
#  datetime.datetime(2014, 1, 29, 0, 0),
#  datetime.datetime(2014, 2, 18, 0, 0),
#  datetime.datetime(2014, 3, 10, 0, 0),
#  datetime.datetime(2014, 3, 30, 0, 0),
#  datetime.datetime(2014, 4, 19, 0, 0),
#  datetime.datetime(2014, 5, 9, 0, 0),
# ...

# %%
# x axis by quarter
line = plot(d, range(12))[0]
line.axes.xaxis.set_major_locator(MonthLocator(range(1,12,3)))
line.axes.xaxis.set_major_formatter(DateFormatter('%d.%b.%Y'))

# %%
clf()

# %%
plot(arange(10))
#t1 = text(5,5,'Text in the middle')
#t2 = figtext(0.8, 0.8, 'Upper right text')
ax = annotate("here is something special", xy=(1,1))
myplot = gca()
line = myplot.lines[0]
an = line.axes.annotate('My text', xy=(1,1), xytext=(1,5),arrowprops={'facecolor':'r'})

# %%
an.remove()

# %%
draw()

# %%
#nope - need qtconsole for this

# %%
# look for fig=gcf(); fig.setfacecolor('r')
